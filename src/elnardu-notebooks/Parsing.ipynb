# %%
import requests
from lxml import etree
import pandas as pd
from fake_useragent import UserAgent
from tqdm import tqdm

# %%
ARGUMAN_ROOT_URL = "https://en.arguman.org"
FALLACIES_PAGE_URL = ARGUMAN_ROOT_URL + "/fallacies"
ARGUMAN_API_URL = ARGUMAN_ROOT_URL + "/api/v1"

HTML_PARSER = etree.HTMLParser()

# %%
ua = UserAgent()
user_agent_header = {"User-Agent": ua.chrome}

# %%
def load_reports(offset=0):
    res = requests.get(FALLACIES_PAGE_URL,
                       headers=user_agent_header,
                       params={'offset': offset})

    res.raise_for_status()  # make sure request is successful
    root = etree.fromstring(res.text, HTML_PARSER)
    return root.xpath('//*[@class="fallacy-report"]')

# %%
def parse_report(report):
    title = report.xpath('div/h2/a/text()')[0].strip()
    url = ARGUMAN_ROOT_URL + report.xpath('div/h2/a/@href')[0]
    premise_content = report.xpath('div/div[1]/text()')[0].strip()

    try:
        premise_type = next(
            filter(lambda x: x in {'but', 'because', 'however'},
                   report.xpath('div/div[1]/@class')[0].split()))
    except StopIteration:
        premise_type = None

    fallacy_type = report.xpath('div/div[2]/h4/text()')[0]
    fallacy_reason = report.xpath('div/div[2]/text()')[1].strip()
    
    return {
        'title': title,
        'url': url,
        'premise_content': premise_content,
        'premise_type': premise_type,
        'fallacy_type': fallacy_type,
        'fallacy_reason': fallacy_reason
    }

# %%
reports = []
for offset in tqdm(range(0, 1000, 10)):
    for raw_report in load_reports(offset=offset):
        reports.append(parse_report(raw_report))
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]

# %%
df = pd.DataFrame(reports)

# %%
df
# Out:
#                                         fallacy_reason  \
# 0    it does not matter what others do, only the ra...
# 1    Relies on the Authority of Abraham Lincoln bei...
# 2                 Bananas has nothing to do with this.
# 3    This premises unnecessarily discusses other re...
# 4                                           s;piderman
# 5                                           s;piderman
# 6                                           s;piderman
# 7    There is a correlation between their success a...
# 8    Why is the creator outside of this cause-and-e...
# 9    This argument assumes the premise "Science has...
# 10                                 This is irrelevant!
# 11   There is no reason why code should look terrib...
# 12   the premise seeks to counter the initial premi...
# 13                                 This is an opinion.
# 14                          "Or 1" always return true.
# 15           But that does not make his point invalid.
# 16         It is not about Kimmel but about gun policy
# 17   What is does not ought or have to be always. Y...
# 18   Being a monarch does not necessarily mean to b...
# 19   Gracias por esa definición que no conocíamos y...
# 20   While drug addiction is a form of mental illne...
# 21   And? That doesn't mean anything about if it's ...
# 22         Appeal to ridicule by exploiting a wordplay
# 23   This is just pointing out a mathematical mista...
# 24   Claim without argument or proof; also, not add...
# 25             The premise about omit-able semicolons.
# 26   Whatever it is pointless or not has nothing to...
# 27   How a character looks like has nothing to do w...
# 28           This has nothing to do with the argument.
# 29             This is implicit in the original claim.
# ..                                                 ...
# 887                                    Har inget stöd.
# 888  You don't understand what a theory is in the s...
# 889  Pointless semantics to an already incorrect co...
# 890                              Meaningless semantics
# 891  There must be A, because we know that B exists...
# 892              This argument is about vim and emacs.
# 893  It does not matter that it is not the study of...
# 894                     irrelevant to the conversation
# 895  Vim is not an integrated development environme...
# 896  Aside from the notion that suffering is more p...
# 897  Historical truths cannot be rewritten by a pre...
# 898  The scientific "laws" are human approximations...
# 899                                  ad hominem attack
# 900                       Adds nothing to the argument
# 901  Ethnical diversity does not neccessarily mean ...
# 902  Doesn't explain why. The whole original premis...
# 903  The topic is that creationism is not compatibl...
# 904  I'm not sure the exact fallacy, but you cant j...
# 905                   Has nothing to do with argument.
# 906  It does not need evidence to fit with the subj...
# 907                                        No evidence
# 908  Saying what is ("it’s natural", "it is how nat...
# 909  It does not follow from the previous point, no...
# 910  asserts that some event must inevitably follow...
# 911             Assertion without any logical support.
# 912  The actual fallacy is "Appeal to Tradition", b...
# 913  Very poor, unproven study.\nhttp://motherboard...
# 914  Because calling Iran a troll master (sourcing ...
# 915                           Argument from ignorance.
# 916  The conclusion reached is not related to the o...
#
#                       fallacy_type  \
# 0              Appeal To Authority
# 1              Appeal To Authority
# 2            Irrelevant Conclusion
# 3            Irrelevant Conclusion
# 4             Begging The Question
# 5             Begging The Question
# 6             Begging The Question
# 7           Fallacy Of False Cause
# 8      Fallacy Of Special Pleading
# 9             Begging The Question
# 10           Irrelevant Conclusion
# 11                Appeal To Belief
# 12              Poisoning The Well
# 13                Appeal To Belief
# 14                   False Analogy
# 15           Irrelevant Conclusion
# 16         Argument Against TheMan
# 17          Fallacy Of Is To Ought
# 18          Fallacy Of False Cause
# 19            Begging The Question
# 20           Irrelevant Conclusion
# 21          Fallacy Of Red Herring
# 22          Fallacy Of Red Herring
# 23              Poisoning The Well
# 24            Begging The Question
# 25           Irrelevant Conclusion
# 26           Irrelevant Conclusion
# 27           Irrelevant Conclusion
# 28           Irrelevant Conclusion
# 29            Begging The Question
# ..                             ...
# 887          Irrelevant Conclusion
# 888                  False Analogy
# 889          Irrelevant Conclusion
# 890          Irrelevant Conclusion
# 891           Begging The Question
# 892         Fallacy Of Red Herring
# 893          Irrelevant Conclusion
# 894          Irrelevant Conclusion
# 895                  False Analogy
# 896         Fallacy Of False Cause
# 897            Appeal To Authority
# 898          Irrelevant Conclusion
# 899        Argument Against TheMan
# 900               Appeal To Belief
# 901          Irrelevant Conclusion
# 902           Begging The Question
# 903          Irrelevant Conclusion
# 904               Appeal To Belief
# 905         Fallacy Of Red Herring
# 906          Irrelevant Conclusion
# 907               Appeal To Belief
# 908         Fallacy Of Is To Ought
# 909  Fallacy Of Irrelevant Purpose
# 910      Fallacy Of Slippery Slope
# 911           Begging The Question
# 912         Fallacy Of Is To Ought
# 913         Fallacy Of False Cause
# 914             Poisoning The Well
# 915          Irrelevant Conclusion
# 916          Irrelevant Conclusion
#
#                                        premise_content premise_type  \
# 0    No other international movement/NGO/protest gr...      because
# 1           Abraham believed slavery was morally wrong      because
# 2                                    Bananas are blue.          but
# 3    If Islam is not a religion of peace, then no o...      however
# 4    The attack in Selma left many dead and it was ...      because
# 5    African Americans have been oppressed by the w...      because
# 6    America is still living in a racist time again...          but
# 7    Very prominant figures in our history, such as...          but
# 8    The creator doesn't have to have been created,...          but
# 9           Science has proved that God does not exist      however
# 10            It's another THING we have to deal with!      however
# 11   But this matter when you send file to another ...          but
# 12   Is "force everyone to learn what I see as trut...          but
# 13               Magic mouse is a bad mouse in general          but
# 14   the mutual intelligibility barrier between hum...          but
# 15   That's a very large leap. I think it's pretty ...          but
# 16                                 Kimmel is ignorant.      because
# 17   The meme of democratic reign and maximization ...          but
# 18                    A monarch is highly corruptible.          but
# 19   Te contraresto el ejemplo porque es malo con g...          but
# 20   When a person consumes a lot of drugs, his mot...      because
# 21                              But Everybody Does it!          but
# 22   A semicolon `;` consists of a comma `,` and a ...      however
# 23   A function that suffers off-by-one errors clea...          but
# 24                                          Java sucks      however
# 25   It is impossible to write a for loop without s...          but
# 26                             javascript is pointless      because
# 27   A semicolon `;` consists of a comma `,` and a ...      however
# 28                             Potatoes are delicious.      because
# 29   Culture affects the way different races act an...      because
# ..                                                 ...          ...
# 887  Vårt välfärdssystem rimligen klarar av de 140....      because
# 888  The theories that science is based on are just...          but
# 889                                                         however
# 890  Acknowledging a fact does not indicate guilt. ...      however
# 891  I can deduce that there's something beyond the...          but
# 892  Both have been succeeded by better text editor...      however
# 893  Computer science... differs from physics in th...      because
# 894                        it is the other way around.          but
# 895  Both have been succeeded by better text editor...      however
# 896  The value of life is ultimately negative becau...      because
# 897  Isn't David Irving the known racist anti-semit...      however
# 898  The existence of scientific law is itself evid...          but
# 899                 You don’t understand what WASM is.      however
# 900                     It most definitely did though.          but
# 901  The lack of a common unified culture means peo...      because
# 902  Social benefits should be considered a right r...          but
# 903  The burden of proof is on the creationist to p...          but
# 904                     It most definitely did though.          but
# 905    Nice clickbait title. EDIT: no longer clickbait      however
# 906    There is not a single piece of evidence for it.      because
# 907                                        impossible.          but
# 908  It's natural for animals to eat meat. You can'...      however
# 909                  Even assisted suicide is immoral.          but
# 910  you get stoned and hungry and you will spend a...          but
# 911                 We should not lie to our children!          but
# 912  It is a tradition, not some sort of religion o...      because
# 913  Recent studies show that even moderate use of ...          but
# 914                             They are troll Masters          but
# 915  What constitutes 'creationism'? What evidence ...          but
# 916  uncertainy can be nice. you know,... the facin...          but
#
#                                                  title  \
# 0              FFF International should leave Telegram
# 1                               Slaves should be freed
# 2     Contributor should always be default beneficiary
# 3                        Islam is a religion of peace.
# 4    African Americans should be able to vote-We sh...
# 5    African Americans should be able to vote-We sh...
# 6    African Americans should be able to vote-We sh...
# 7                           Introverts are Undervalued
# 8                                 A creator must exist
# 9                    The God of the bible loves people
# 10              We should try out the Arguman platform
# 11   Tabs are better than spaces for indentation (p...
# 12   Teaching evolution in biology classes should b...
# 13   Ctrl+Click is better than right click if you u...
# 14               Plants should have the right to vote.
# 15         Postmortem organ donation should be opt-out
# 16   Jimmy Kimmel should not bring up inaction on g...
# 17           A monarchy is the best form of government
# 18           A monarchy is the best form of government
# 19                El lenguaje inclusivo es innecesario
# 20   Society suffers the most when dealing with peo...
# 21   Illegally downloading copyrighted music and ot...
# 22             Semi-colons are pointless in Javascript
# 23   You can't measure how good a programming langu...
# 24   You can't measure how good a programming langu...
# 25             Semi-colons are pointless in Javascript
# 26             Semi-colons are pointless in Javascript
# 27             Semi-colons are pointless in Javascript
# 28   Everything in the universe is either a potato,...
# 29   Life in America has nothing to do with race, b...
# ..                                                 ...
# 887  Svenska regeringens ändring av flyktingpolitik...
# 888  Creationism is not compatible with current sci...
# 889                           React is killing Angular
# 890                           React is killing Angular
# 891  Creationism is not compatible with current sci...
# 892                           Vim is better than emacs
# 893         Computer Science is not actually a science
# 894  An adult child has a moral responsibility to c...
# 895                           Vim is better than emacs
# 896                          Life is not worth living.
# 897                        The Holocaust didn't happen
# 898  Creationism is not compatible with current sci...
# 899                           React is killing Angular
# 900                        The Holocaust didn't happen
# 901  Ethnic diversity reduces social solidarity and...
# 902  The unemployed should be made to do community ...
# 903  Creationism is not compatible with current sci...
# 904                        The Holocaust didn't happen
# 905   ISIS wants Christians and Muslims to fight a war
# 906  Creationism is not compatible with current sci...
# 907                             Evolution is not fact.
# 908                         We should stop to eat meat
# 909                   Cannibalism is inherently wrong.
# 910                       Cannabis usage is beneficial
# 911  We must tell our children about Santa Claus (o...
# 912  We must tell our children about Santa Claus (o...
# 913         Recreational Marijuana should be legalized
# 914  We should trust Iran to maintain a peaceful nu...
# 915  Creationism is not compatible with current sci...
# 916  The world view that makes the fewest assumptio...
#
#                                                    url
# 0    https://en.arguman.org/fff-international-shoul...
# 1        https://en.arguman.org/slaves-should-be-freed
# 2    https://en.arguman.org/contributor-should-alwa...
# 3    https://en.arguman.org/islam-is-a-religion-of-...
# 4    https://en.arguman.org/african-americans-shoul...
# 5    https://en.arguman.org/african-americans-shoul...
# 6    https://en.arguman.org/african-americans-shoul...
# 7    https://en.arguman.org/the-greater-our-knowled...
# 8          https://en.arguman.org/a-creator-must-exist
# 9    https://en.arguman.org/the-god-of-the-bible-lo...
# 10   https://en.arguman.org/we-should-try-out-the-a...
# 11   https://en.arguman.org/tabs-are-better-than-sp...
# 12   https://en.arguman.org/teaching-evolution-in-b...
# 13   https://en.arguman.org/ctrlclick-is-better-tha...
# 14   https://en.arguman.org/plants-should-have-the-...
# 15   https://en.arguman.org/postmortem-organ-donati...
# 16   https://en.arguman.org/jimmy-kimmel-should-not...
# 17   https://en.arguman.org/a-monarchy-is-the-best-...
# 18   https://en.arguman.org/a-monarchy-is-the-best-...
# 19   https://en.arguman.org/el-lenguaje-inclusivo-e...
# 20   https://en.arguman.org/society-suffers-the-mos...
# 21   https://en.arguman.org/why-illegally-downloadi...
# 22   https://en.arguman.org/semi-colons-are-unneces...
# 23   https://en.arguman.org/you-cant-measure-how-go...
# 24   https://en.arguman.org/you-cant-measure-how-go...
# 25   https://en.arguman.org/semi-colons-are-unneces...
# 26   https://en.arguman.org/semi-colons-are-unneces...
# 27   https://en.arguman.org/semi-colons-are-unneces...
# 28   https://en.arguman.org/everything-in-the-unive...
# 29   https://en.arguman.org/life-in-america-has-not...
# ..                                                 ...
# 887  https://en.arguman.org/svenska-regeringens-and...
# 888  https://en.arguman.org/creationism-is-not-comp...
# 889    https://en.arguman.org/react-is-killing-angular
# 890    https://en.arguman.org/react-is-killing-angular
# 891  https://en.arguman.org/creationism-is-not-comp...
# 892    https://en.arguman.org/vim-is-better-than-emacs
# 893  https://en.arguman.org/computer-science-is-not...
# 894  https://en.arguman.org/an-adult-child-has-a-mo...
# 895    https://en.arguman.org/vim-is-better-than-emacs
# 896    https://en.arguman.org/life-is-not-worth-living
# 897  https://en.arguman.org/the-holocaust-didnt-hap...
# 898  https://en.arguman.org/creationism-is-not-comp...
# 899    https://en.arguman.org/react-is-killing-angular
# 900  https://en.arguman.org/the-holocaust-didnt-hap...
# 901  https://en.arguman.org/ethnic-diversity-reduce...
# 902  https://en.arguman.org/the-unemployed-should-b...
# 903  https://en.arguman.org/creationism-is-not-comp...
# 904  https://en.arguman.org/the-holocaust-didnt-hap...
# 905  https://en.arguman.org/isis-wants-christians-a...
# 906  https://en.arguman.org/creationism-is-not-comp...
# 907       https://en.arguman.org/evolution-is-not-fact
# 908  https://en.arguman.org/we-should-stop-to-eat-meat
# 909  https://en.arguman.org/cannibalism-is-inherent...
# 910  https://en.arguman.org/cannabis-usage-is-benef...
# 911  https://en.arguman.org/we-must-tell-our-childr...
# 912  https://en.arguman.org/we-must-tell-our-childr...
# 913  https://en.arguman.org/recreational-marijuana-...
# 914  https://en.arguman.org/we-should-trust-iran-to...
# 915  https://en.arguman.org/creationism-is-not-comp...
# 916  https://en.arguman.org/the-world-view-that-mak...
#
# [917 rows x 6 columns]

# %%
df.to_csv('../data/fallacies.csv')

# %%
# (0 for but, 1 for because, 2 for however)
# from https://github.com/arguman/arguman.org/blob/master/docs/api/arguments/create_premise.md
PREMISE_TYPE_TO_TEXT = {
    0: 'but',
    1: 'because',
    2: 'however'
}

# %%
def get_approved_premises(title):
    res = requests.get(ARGUMAN_API_URL + '/arguments',
                       headers=user_agent_header,
                       params={'search': title})
    res.raise_for_status()
    argument_json = res.json()

    if argument_json['count'] == 0:
        return []
    
    argument_title = argument_json['results'][0]['title']
    url = ARGUMAN_ROOT_URL + '/' + argument_json['results'][0]['slug']

    premises = []

    for premise in argument_json['results'][0]['premises']:
        if len(premise['supporters']) == 0:
            continue

        if not premise['parent']:  # only get parents of the root argument
            continue

        premise_content = premise['text']
        premise_type = PREMISE_TYPE_TO_TEXT[premise['premise_type']]
        n_supporters = len(premise['supporters'])

        premises.append({
            'title': argument_title,
            'url': url,
            'premise_content': premise_content,
            'premise_type': premise_type,
            'fallacy_type': 'None',
            'fallacy_reason': '',
            'n_supporters': n_supporters
        })

    return premises

# %%
approved_premises = []
for _, row in tqdm(df.iterrows()):
    approved_premises += get_approved_premises(row.title)
# Out:
# 917it [06:39,  2.30it/s]

# %%
approved_df = pd.DataFrame(approved_premises)

# %%
approved_df.to_csv('../data/approved.csv')
